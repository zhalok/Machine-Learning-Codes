# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# %%
#lets create a random data set which is not linear

x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)
print(x.shape)
print(y.shape)
plt.scatter(x,y)
# Out:
# (20,)
# (20,)

# %%
x_ = x.reshape(-1,1)
print(x_.shape)
# Out:
# (20, 1)

# %%
linear_reg_model = LinearRegression()
linear_reg_model.fit(x_,y)
# Out:
# LinearRegression()

# %%
plt.plot(x,linear_reg_model.predict(x_))
plt.scatter(x,y)

# %%
polynomial_features = PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x_)
print(x_poly)
# Out:
# [[ 1.00000000e+00  2.01263181e+00  4.05068679e+00  8.15254106e+00]
#  [ 1.00000000e+00  4.82900744e+00  2.33193128e+01  1.12609135e+02]
#  [ 1.00000000e+00  1.77437162e+00  3.14839466e+00  5.58642213e+00]
#  [ 1.00000000e+00  3.59864285e+00  1.29502303e+01  4.66032538e+01]
#  [ 1.00000000e+00  4.47274619e+00  2.00054585e+01  8.94793382e+01]
#  [ 1.00000000e+00  2.31764767e-01  5.37149070e-02  1.24492229e-02]
#  [ 1.00000000e+00  4.38140008e+00  1.91966667e+01  8.41082768e+01]
#  [ 1.00000000e+00 -3.66488482e+00  1.34313807e+01 -4.92244633e+01]
#  [ 1.00000000e+00 -2.62491202e-01  6.89016313e-02 -1.80860720e-02]
#  [ 1.00000000e+00  1.52700466e+00  2.33174323e+00  3.56058277e+00]
#  [ 1.00000000e+00 -3.76629359e-02  1.41849674e-03 -5.34247519e-05]
#  [ 1.00000000e+00  5.69941827e+00  3.24833686e+01  1.85136304e+02]
#  [ 1.00000000e+00 -4.44641827e-01  1.97706354e-01 -8.79085144e-02]
#  [ 1.00000000e+00 -1.56335976e+00  2.44409372e+00 -3.82099777e+00]
# ...

# %%
linear_reg_model.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
preds = linear_reg_model.predict(x_poly)
plt.plot(sorted(x),sorted(preds))
plt.scatter(x,y)
